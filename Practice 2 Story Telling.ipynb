# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
death_toll = pd.read_csv('avg_deaths.csv')

# %%
death_toll
# Out:
#     Month  New_deaths
# 0       1           0
# 1       2           0
# 2       3          77
# 3       4        1844
# 4       5        1448
# 5       6         785
# 6       7         769
# 7       8        1020
# 8       9         739
# 9      10         751
# 10     11        1225
# 11     12        2247

# %%
fig ,[ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4 ,ncols = 1 , figsize = (5,8))

axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll['Month'] , death_toll['New_deaths'])
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.tick_params(left=0 ,bottom = 0)
    ax.text(0.5,-1 ,'0')
    ax.text(12,2400 ,'2247')
    for location in ('left' , 'right' , 'top' ,'bottom'):
        ax.spines[location].set_visible(False)
        
ax1.plot(death_toll['Month'][:3] , death_toll['New_deaths'][:3] , linewidth = 5 ,color = "#7fad27")
ax2.plot(death_toll['Month'][2:6] , death_toll['New_deaths'][2:6] , linewidth = 5 ,color = "#7fad27")
ax3.plot(death_toll['Month'][5:10] , death_toll['New_deaths'][5:10] , linewidth = 5 ,color = "#7fad27")
ax4.plot(death_toll['Month'][9:] , death_toll['New_deaths'][9:] , linewidth = 5 ,color = "#7fad27")
    
 
plt.show()

# %%
fig ,[ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4 ,ncols = 1 , figsize = (5,8))

axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll['Month'] , death_toll['New_deaths'] , color = '#af0b1e')
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.tick_params(left=0 ,bottom = 0)
    ax.text(0.5,-1 ,'0')
    ax.text(12,2400 ,'2247')
    for location in ('left' , 'right' , 'top' ,'bottom'):
        ax.spines[location].set_visible(False)
        
ax1.plot(death_toll['Month'][:3] , death_toll['New_deaths'][:3] , linewidth = 3 ,color = "#7fad27")
ax2.plot(death_toll['Month'][2:6] , death_toll['New_deaths'][2:6] , linewidth = 3 ,color = "#7fad27")
ax3.plot(death_toll['Month'][5:10] , death_toll['New_deaths'][5:10] , linewidth = 3 ,color = "#7fad27")
ax4.plot(death_toll['Month'][9:] , death_toll['New_deaths'][9:] , linewidth = 3 ,color = "#7fad27")

ax1.text(1,-400, 'Jan - Mar' , weight = 'bold', rotation =5)
ax2.text(3.5, 600, 'April - June' ,weight = 'bold')
ax3.text(7,400,'July - Sep', weight = 'bold')
ax4.text(11.5,1000 , 'Oct - Dec' ,weight = 'bold' , rotation = 30)
        

    
 
plt.show()

# %%
fig ,[ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4 ,ncols = 1 , figsize = (5,8))

axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll['Month'] , death_toll['New_deaths'] , color = '#af0b1e')
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.tick_params(left=0 ,bottom = 0)
    ax.text(0.5,-1 ,'0')
    ax.text(12,2400 ,'2247')
    for location in ('left' , 'right' , 'top' ,'bottom'):
        ax.spines[location].set_visible(False)
        
ax1.plot(death_toll['Month'][:3] , death_toll['New_deaths'][:3] , linewidth = 3 ,color = "#7fad27")
ax2.plot(death_toll['Month'][2:6] , death_toll['New_deaths'][2:6] , linewidth = 3 ,color = "#7fad27")
ax3.plot(death_toll['Month'][5:10] , death_toll['New_deaths'][5:10] , linewidth = 3 ,color = "#7fad27")
ax4.plot(death_toll['Month'][9:] , death_toll['New_deaths'][9:] , linewidth = 3 ,color = "#7fad27")

ax1.text(1,-400, 'Jan - Mar' , weight = 'bold', rotation =5)
ax2.text(3.5, 600, 'April - June' ,weight = 'bold')
ax3.text(7,400,'July - Sep', weight = 'bold')
ax4.text(11.5,1000 , 'Oct - Dec' ,weight = 'bold' , rotation = 30)

ax1.axhline(xmin=0.5 ,xmax = 0.8 , y = 1600 , linewidth = 6 , color = '#7fad27' , alpha = 0.5)
    
 
plt.show()

# %%
fig ,[ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4 ,ncols = 1 , figsize = (5,8))

axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll['Month'] , death_toll['New_deaths'] , color = '#af0b1e')
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.tick_params(left=0 ,bottom = 0)
    ax.text(0.5,-1 ,'0')
    ax.text(12,2400 ,'2247')
    for location in ('left' , 'right' , 'top' ,'bottom'):
        ax.spines[location].set_visible(False)
        
ax1.plot(death_toll['Month'][:3] , death_toll['New_deaths'][:3] , linewidth = 3 ,color = "#7fad27")
ax2.plot(death_toll['Month'][2:6] , death_toll['New_deaths'][2:6] , linewidth = 3 ,color = "#7fad27")
ax3.plot(death_toll['Month'][5:10] , death_toll['New_deaths'][5:10] , linewidth = 3 ,color = "#7fad27")
ax4.plot(death_toll['Month'][9:] , death_toll['New_deaths'][9:] , linewidth = 3 ,color = "#7fad27")

ax1.text(1,-400, 'Jan - Mar' , weight = 'bold', rotation =5)
ax2.text(3.5, 500, 'April - June' ,weight = 'bold')
ax3.text(7,400,'July - Sep', weight = 'bold')
ax4.text(11.5,1000 , 'Oct - Dec' ,weight = 'bold' , rotation = 30)

for ax in axes:
    ax.axhline(xmin = 0.5 , xmax = 0.8 , y = 1600 , color = '#7fad27' , alpha = 0.5 ,linewidth = 5)
        

    
 
plt.show()

# %%
death_value = []
start = 0
end = 3

for i in range(4):
    death_value.append(death_toll['New_deaths'][start:end].sum())
    start += 3
    end += 3

# %%
death_value
# Out:
# [77, 4077, 2528, 4223]

# %%
death_value = []
start = 0
end = 3

for i in range(4):
    death_value.append(death_toll['New_deaths'][start:end].sum())
    start += 3
    end += 3

# %%
death_value
# Out:
# [77, 4077, 2528, 4223]

# %%
deaths = []
end = 3

for i in range(4):
    deaths.append(death_toll['New_deaths'][:end].sum())
    end += 3

# %%
deaths
# Out:
# [77, 4154, 6682, 10905]

# %%
total_deaths = death_toll['New_deaths'].sum()
total_deaths
# Out:
# 10905

# %%
prop = np.round (deaths/total_deaths, 3)
prop
# Out:
# array([0.007, 0.381, 0.613, 1.   ])

# %%
0.5 + prop * 0.3
# Out:
# array([0.5021, 0.6143, 0.6839, 0.8   ])

# %%
xmax_value = [0.5 + pro * 0.3 for pro in prop]
xmax_value
# Out:
# [0.5021, 0.6143, 0.6839, 0.8]

# %% [markdown]
# fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4, ncols = 1 , figsize = (5,8))
#
# axes = [ax1,ax2,ax3,ax4]
#
# for ax in axes:
#     ax.plot(death_toll['Month'] , death_toll['New_deaths'] , color = '#af0b1e')
#     ax.set_xticklabels([])
#     ax.set_yticklabels([])
#     ax.tick_params(left = 0 , bottom = 0)
#     ax.text(0.5,-50, '0')
#     ax.text(12,2400 , '2247')
#     for location in ['left' , 'right' , 'top' ,'bottom']:
#         ax.spines[location].set_visible(False)
#
# ax1.plot(death_toll['Month'][:3] , death_toll['New_deaths'][:3] , linewidth = 3 , color = '#7fad27')
# ax2.plot(death_toll['Month'][2:6] , death_toll['New_deaths'][2:6] , linewidth = 3 , color = '#7fad27')
# ax3.plot(death_toll['Month'][5:10] , death_toll['New_deaths'][5:10] , linewidth = 3 , color = '#7fad27')
# ax4.plot(death_toll['Month'][9:] , death_toll['New_deaths'][9:] , linewidth = 3 , color = '#7fad27')
#
# ax1.text(2 ,-50 , 'Jan-Mar')

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4, ncols = 1 , figsize = (5,8))

axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll['Month'] , death_toll['New_deaths'] , color = '#af0b1e')
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.tick_params(left = 0 , bottom = 0)
    ax.text(0.5,-50, '0')
    ax.text(12,2400 , '2247')
    for location in ['left' , 'right' , 'top' ,'bottom']:
        ax.spines[location].set_visible(False)

ax1.plot(death_toll['Month'][:3] , death_toll['New_deaths'][:3] , linewidth = 3 , color = '#7fad27')
ax2.plot(death_toll['Month'][2:6] , death_toll['New_deaths'][2:6] , linewidth = 3 , color = '#7fad27')
ax3.plot(death_toll['Month'][5:10] , death_toll['New_deaths'][5:10] , linewidth = 3 , color = '#7fad27')
ax4.plot(death_toll['Month'][9:] , death_toll['New_deaths'][9:] , linewidth = 3 , color = '#7fad27')

ax1.text(1.4 ,-300 , 'Jan-Mar')
ax2.text(3.5, 500 , 'Apr - June')
ax3.text(7, 400 ,'July - Sep')
ax4.text(11, 900 ,'Oct - Dec' , rotation = 60)

for ax , xmax_v , death in zip (axes , xmax_value, death_value):
    ax.axhline(xmin = 0.5 , xmax = 0.8 , y = 1600 , linewidth = 4 , alpha = 0.3 )
    ax.axhline(xmin = 0.5 , xmax = xmax_v , y = 1600 , linewidth = 4 )
    ax.text(7.5, 1800 , format(death ,  ","))

plt.show()

# %%
fig , [(ax1,ax2),(ax3,ax4),(ax5,ax6)] = plt.subplots(nrows = 3 , ncols = 2 , figsize = (7,9))

axes = [(ax1,ax2),(ax3,ax4),(ax5,ax6)]

for ax_pair in axes:
    ax1,ax2 = ax_pair
    ax1.plot(death_toll['Month'] , death_toll['New_deaths'])
    ax2.plot(death_toll['Month'] , death_toll['New_deaths'])
    ax1.set_xticklabels([])
    ax2.set_xticklabels([])
    ax1.set_yticklabels([])
    ax2.set_yticklabels([])
    ax1.tick_params(left =0 , bottom=0 )
    ax2.tick_params(left =0 , bottom=0 )
    for location in ['top' , 'left' , 'bottom' , 'top']:
        ax1.spines[location].set_visible(False)
        ax2.spines[location].set_visible(False)



plt.show()
